# %% [markdown]
# # vector_store.py — Overview
#
# This notebook documents vector store helpers (upsert, search, stats). It guards imports for Qdrant and embedding libs.

# %%
try:
    import app.vector_store as vs
    print('Imported app.vector_store')
except Exception as e:
    print('Could not import app.vector_store:', e)

# %% [markdown]
# ## Example: create and inspect a small in-memory index (demo)
# These calls will use demo stubs if available.

# %%
if 'app.vector_store' in globals():
    try:
        stats = vs.stats() if hasattr(vs, 'stats') else None
        print('Stats:', stats)
    except Exception as e:
        print('Vector store call failed:', e)
else:
    print('vector_store not present — skip')
