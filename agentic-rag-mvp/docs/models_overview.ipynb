# %% [markdown]
# # models.py — Overview
#
# This notebook documents the data models (Pydantic/Dataclasses) used across the project. It uses guarded imports so it opens safely without external deps.

# %%
try:
    import app.models as models
    print('Imported app.models')
except Exception as e:
    print('Could not import app.models:', e)

# %% [markdown]
# ## Example: list public model classes
# If `models` is available, list top-level classes to help you integrate with the rest of the project.

# %%
if 'models' in globals():
    try:
        print('Public model names:', [n for n in dir(models) if n[0].isupper()][:60])
    except Exception as e:
        print('Listing failed:', e)
else:
    print('models module not present — skip')
