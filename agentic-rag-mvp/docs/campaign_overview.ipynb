# %% [markdown]
# # campaign.py — Overview
#
# This notebook documents campaign helpers (setup, featured books, prize rules) with guarded imports so it opens cleanly in demo environments.

# %%
# Safe import
try:
    import app.campaign as campaign
    print('Imported app.campaign')
except Exception as e:
    print('Could not import app.campaign:', e)

# %% [markdown]
# ## Example usage (demo-safe)
# Try calling the main helpers if present.

# %%
if 'campaign' in globals():
    try:
        if hasattr(campaign, 'apply_campaign_settings'):
            print('apply_campaign_settings found')
    except Exception as e:
        print('Example call failed:', e)
else:
    print('campaign module not present — skip examples')
