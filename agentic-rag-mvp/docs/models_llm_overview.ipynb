# %% [markdown]
# # models_llm.py — Overview
#
# This notebook documents the LLM model abstractions and helper types defined in `models_llm.py`. It uses guarded imports so the notebook opens cleanly even without model binaries or heavy deps.

# %%
# Safe import pattern
try:
    import app.models_llm as models_llm
    print('Imported app.models_llm')
except Exception as e:
    print('Could not import app.models_llm:', e)

# %% [markdown]
# ## Example: inspect model classes/types
# If the module is present, list the main attributes and types to help you integrate models safely.

# %%
if 'models_llm' in globals():
    try:
        print('Public attrs:', [a for a in dir(models_llm) if not a.startswith('_')][:60])
    except Exception as e:
        print('Inspection failed:', e)
else:
    print('models_llm not present — skip')
