# %% [markdown]
# # rag.py — Overview
#
# Documenting RAG upload and retrieval helpers. The notebook uses guarded imports so it can be opened without a vector DB or embedding service.

# %%
try:
    import app.rag as rag
    print('Imported app.rag')
except Exception as e:
    print('Could not import app.rag:', e)

# %% [markdown]
# ## Example: safe upload flow
# Call `rag.ui_rag_upload` or similar functions if present. These examples are guarded.

# %%
if 'rag' in globals():
    try:
        if hasattr(rag, 'ui_rag_upload'):
            print('ui_rag_upload exists — demo safe')
    except Exception as e:
        print('RAG example failed:', e)
else:
    print('rag not present — skip')
