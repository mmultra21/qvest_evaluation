# %% [markdown]
# # router.py — Overview
#
# This notebook explains the routing logic used to choose between vector, web, or direct LLM paths. It uses guarded imports so it opens in demo mode without external services.

# %%
# Safe import for the router module
try:
    import app.router as router
    print('Imported app.router')
except Exception as e:
    print('Could not import app.router:', e)
# Out:
# Could not import app.router: No module named 'app'

# %% [markdown]
# ## Example decision call
# If available, call the router with a sample question to see the chosen route.

# %%
if 'app.router' in globals():
    try:
        plan = router.route_recency_aware('When was the Declaration of Independence signed?', allow_web=True)
        print('Plan:', plan)
    except Exception as e:
        print('Router call failed:', e)
else:
    print('router not present — skipping')
# Out:
# router not present — skipping
