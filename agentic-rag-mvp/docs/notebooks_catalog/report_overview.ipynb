# %% [markdown]
# # report.py — Overview
#
# Notebook documenting reporting helpers (metrics export, leaderboards, JSON/CSV export). It uses guarded imports and example calls.

# %%
try:
    import app.report as report
    print('Imported app.report')
except Exception as e:
    print('Could not import app.report:', e)

# %% [markdown]
# ## Example: export JSON/CSV
# Call `report.export_metrics_json` or similar helpers if present — examples are guarded.

# %%
if 'report' in globals():
    try:
        if hasattr(report, 'export_metrics_json'):
            print('export_metrics_json available — demo safe')
    except Exception as e:
        print('Report example failed:', e)
else:
    print('report module not present — skip')
