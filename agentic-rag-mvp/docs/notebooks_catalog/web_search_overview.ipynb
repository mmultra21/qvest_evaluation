# %% [markdown]
# # web_search.py — Overview
#
# Notebook describing web search helpers (SerpAPI integration) and safe usage. It uses guarded imports so it can open without a SERPAPI key.

# %%
try:
    import app.web_search as web_search
    print('Imported app.web_search')
except Exception as e:
    print('Could not import app.web_search:', e)

# %% [markdown]
# ## Example: run a demo safe web query
# If SERPAPI_KEY is missing the helper will return an informative message.

# %%
if 'app.web_search' in globals():
    try:
        res = web_search.serpapi_search('Python programming', num=1) if hasattr(web_search, 'serpapi_search') else None
        print('Search result (demo):', res)
    except Exception as e:
        print('Web search call failed:', e)
else:
    print('web_search not present — skip')
