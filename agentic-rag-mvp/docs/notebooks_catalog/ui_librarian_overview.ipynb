# %% [markdown]
# # ui_librarian.py — Overview
#
# This notebook documents the librarian UI helpers and wiring points. It uses guarded imports and does not attempt to launch Gradio.

# %%
try:
    import app.ui_librarian as ui_librarian
    print('Imported app.ui_librarian')
except Exception as e:
    print('Could not import app.ui_librarian:', e)

# %% [markdown]
# ## Sample usage (safe)
# Call UI helper constructors or event handlers where available. These calls are guarded.

# %%
if 'app.ui_librarian' in globals():
    try:
        comp_map = ui_librarian.build_librarian_ui()
        print('Component map keys:', list(comp_map.keys()))
    except Exception as e:
        print('UI builder failed:', e)
else:
    print('ui_librarian not present — skip')
