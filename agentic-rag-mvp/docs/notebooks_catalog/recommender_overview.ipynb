# %% [markdown]
# # recommender.py — Overview
#
# Notebook covering the recommender helpers (book suggestions, seeds, grade-based filters). Uses guarded imports to avoid heavy deps.

# %%
try:
    import app.recommender as recommender
    print('Imported app.recommender')
except Exception as e:
    print('Could not import app.recommender:', e)

# %%
if 'recommender' in globals():
    try:
        if hasattr(recommender, 'recommend_for_grade'):
            print('recommend_for_grade available')
    except Exception as e:
        print('Recommender example failed:', e)
else:
    print('recommender not present — skip')
