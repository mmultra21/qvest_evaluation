# %% [markdown]
# # ui_student.py — Overview
#
# Notebook documenting student UI helpers, safe import examples, and how to run small smoke tests without Gradio.

# %%
try:
    import app.ui_student as ui_student
    print('Imported app.ui_student')
except Exception as e:
    print('Could not import app.ui_student:', e)

# %%
if 'app.ui_student' in globals():
    try:
        cmap = ui_student.build_student_ui()
        print('Student UI components:', list(cmap.keys()))
    except Exception as e:
        print('Builder failed:', e)
else:
    print('ui_student not present — skipping')
